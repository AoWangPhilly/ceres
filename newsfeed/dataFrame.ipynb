# %%
import pandas as pd

# %%
temp = {'status': 'ok', 'totalResults': 17, 'articles': 
	[
		{'source': 
			{'id': 'bbc-news', 'name': 'BBC News'}, 
			'author': 'https://www.facebook.com/bbcnews', 
			'title': 'Australia firefighters thanked with Times Square billboard', 
			'description': 'The Australian bushfire agency said it wanted to say thanks to helpers in "the biggest way possible".',
			'url': 'https://www.bbc.co.uk/news/world-australia-51555185', 
			'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/C1E3/production/_110953694_sdfsdfsdfsdfsdfsdf.png', 
			'publishedAt': '2020-02-19T05:32:51Z', 
			'content': 'Image copyrightNSWRFSImage caption\r\n The fire service ran their message in Times Square\r\nAn Australian volunteer firefighting service has used a giant, 21m (70ft) tall billboard in Times Square in New York City to thank crew for their work. \r\nMammoth fires whi… [+2211 chars]'}, 
		{'source': 
			{'id': 'bbc-news', 'name': 'BBC News'}, 
			'author': 'BBC News', 
			'title': "Australia fires: Blaze 'sparked by helicopter lights' rages near Canberra", 
			'description': 'The bushfire crisis continues as a national park burns south of Canberra.', 
			'url': 'https://www.bbc.co.uk/news/av/world-australia-51290745/australia-fires-blaze-sparked-by-helicopter-lights-rages-near-canberra', 
			'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/116C8/production/_110686317_p081ng1l.jpg', 
			'publishedAt': '2020-01-29T03:31:57Z', 
			'content': "VideoAn army helicopter's landing lights are thought to have sparked a bushfire burning south of Canberra."}, 
		{'source': 
			{'id': 'bbc-news', 'name': 'BBC News'}, 
			'author': 'https://www.facebook.com/bbcnews', 
			'title': 'Australia fires: NSW inquiry to probe climate change impact', 
			'description': 'The independent inquiry will examine the impact of climate change on the recent bushfires.', 
			'url': 'https://www.bbc.co.uk/news/world-australia-51301917', 
			'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/CAA7/production/_110697815_2afda075-4d7b-4ebf-9e2a-80dbcb6eb95c.jpg', 
			'publishedAt': '2020-01-29T21:33:07Z', 
			'content': 'Image copyrightGetty ImagesImage caption\r\n Fires in NSW have killed 25 people and damaged or destroyed thousands of homes\r\nThe Australian state of New South Wales (NSW) has announced an independent inquiry into the ongoing bushfires, promising to "leave no st… [+1633 chars]'}, 
		{'source': 
			{'id': 'bbc-news', 'name': 'BBC News'}, 
			'author': 'https://www.facebook.com/bbcnews', 
			'title': 'Australia fires: State of emergency declared for Canberra region', 
			'description': 'Huge bushfires are raging near Canberra in the worst threat to the region since 2003, officials say.', 
			'url': 'https://www.bbc.co.uk/news/world-australia-51320333', 
			'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/956B/production/_110715283_1cd21ff6-fc86-460f-b7f8-8b28c40b102d.jpg', 
			'publishedAt': '2020-01-31T02:40:53Z', 
			'content': 'Image copyrightGetty ImagesImage caption\r\n A massive blaze has been burning south of Canberra all week\r\nAuthorities in the Australian Capital Territory (ACT) have declared a state of emergency as massive bushfires rage south of Canberra.\r\nIt is the worst fire… [+1505 chars]'}, 
		{'source': 
			{'id': 'bbc-news', 'name': 'BBC News'}, 
			'author': 'https://www.facebook.com/bbcnews', 
			'title': 'Fire-hit Australia faces flooding threat', 
			'description': 'Severe weather warnings are issued in New South Wales, where rain has helped to douse bushfires.', 
			'url': 'https://www.bbc.co.uk/news/world-australia-51420500', 
			'urlToImage': 'https://ichef.bbci.co.uk/images/ic/1024x576/p082lnr4.jpg', 
			'publishedAt': '2020-02-07T18:44:12Z', 
			'content': "Media caption'Sydney has had its wettest day in well over a year'\r\nThe Australian state of New South Wales (NSW) is braced for severe wet weather this weekend as downpours ease the bushfire crisis in the region. \r\nSevere weather warnings for rain, winds and f… [+4063 chars]"}, 
		{'source': 
			{'id': 'bbc-news', 'name': 'BBC News'}, 
			'author': 'https://www.facebook.com/bbcnews', 
			'title': 'Week in Pictures: 18-24 January', 
			'description': 'A selection of striking news images from around the world this week.', 
			'url': 'https://www.bbc.co.uk/news/in-pictures-51236425', 
			'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/15151/production/_110635368_hi059397633.jpg',
			'publishedAt': '2020-01-25T00:23:34Z', 
			'content': 'A selection of striking news photographs from around the world this week.\r\nImage copyrightAFPImage caption\r\n This aerial photo shows excavators at the construction site of a new hospital being built to treat patients following an outbreak of coronavirus in Wu… [+3149 chars]'}, 
		{'source': 
			{'id': 'bbc-news', 'name': 'BBC News'}, 'author': 'https://www.facebook.com/bbcnews', 
			'title': 'Australia bushfires: Backpackers can stay longer if they help rebuild', 
			'description': 'New rules have been introduced so that people with working holiday visas can extend their stay.', 
			'url': 'https://www.bbc.co.uk/news/newsbeat-51543231', 
			'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/121A/production/_110943640_aus1.jpg', 
			'publishedAt': '2020-02-18T10:16:39Z', 
			'content': "Image copyrightGetty Images\r\nBackpackers in Australia on working holiday visas may now be able to stay longer if they help out on farms that were affected by the bushfires.\r\nPreviously, these visas let people work in the same place for six months - but that's… [+2684 chars]"}, 
		{'source': 
			{'id': 'bbc-news', 'name': 'BBC News'}, 
			'author': None, 
			'title': 'Australian bushfire: Didier Drogba to play in charity game', 
			'description': 'Former Chelsea striker Didier Drogba will join other former players in a charity football match to raise money for the Australian bushfire appeal.', 
			'url': 'https://www.bbc.co.uk/sport/football/51277309', 
			'urlToImage': 'https://ichef.bbci.co.uk/onesport/cps/624/cpsprodpb/12135/production/_110673047_drogba_getty2.jpg', 
			'publishedAt': '2020-01-28T08:16:02Z', 
			'content': 'Drogba played 105 times for Ivory Coast and won four Premier League titles and the 2012 Champions League with Chelsea\r\nFormer Chelsea striker Didier Drogba will join other former players in a charity football match to raise money for the Australian bushfire a… [+1743 chars]'}, 
		{'source': 
			{'id': 'bbc-news', 'name': 'BBC News'}, 
			'author': 'https://www.facebook.com/bbcnews', 
			'title': 'Australia weather: Rain could put out remaining New South Wales blazes', 
			'description': 'Only four blazes remain "uncontained" in the state worst-affected in Australia\'s bushfire crisis.', 
			'url': 'https://www.bbc.co.uk/news/world-australia-51453767', 
			'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/165AC/production/_110846519_gettyimages-1205198448.jpg', 
			'publishedAt': '2020-02-11T01:40:39Z', 
			'content': 'Image copyrightGetty ImagesImage caption\r\n Flooding was widespread across the state\r\nHeavy rains in New South Wales in recent days have led to hopes that all the bushfires in the Australian state could be out by the end of the week.\r\nSince Friday, parts of th… [+3323 chars]'}, 
		{'source': 
			{'id': 'bbc-news', 'name': 'BBC News'}, 
			'author': 'https://www.facebook.com/bbcnews', 
			'title': 'Australia fires: Heavy downbursts extinguish blazes', 
			'description': 'Officials welcome the drenching - but warn of flash floods and storm damage in some areas.', 
			'url': 'https://www.bbc.co.uk/news/world-australia-51409551', 
			'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/1138C/production/_110804507_gettyimages-1204496120.jpg', 
			'publishedAt': '2020-02-07T02:07:22Z', 
			'content': 'Image copyrightGetty ImagesImage caption\r\n The downbursts across much of NSW, including Sydney, will help firefighters\r\nTorrential rain across the east coast of Australia has extinguished a third of the fires and could put out more blazes in the region, offic… [+2944 chars]'}, 
		{'sorce': 
			{'id': 'bbc-news', 'name': 'BBC News'}, 
			'author': 'https://www.facebook.com/bbcnews', 
			'title': 'Australia fires: Residents told to seek shelter in Canberra region', 
			'description': 'Some residents are warned it is too late to leave as multiple fires rage south of Canberra.', 
			'url': 'https://www.bbc.co.uk/news/world-australia-51338314', 
			'urlToImage': 'https://ichef.bbci.co.uk/images/ic/1024x576/p081ngjc.jpg', 
			'publishedAt': '2020-02-01T07:14:57Z', 
			'content': 'Media captionA timelapse of the fires threatening Canberra\r\nA bushfire near the Australian Capital Territory (ACT) grew to more than 35,000 hectares on Saturday, as officials closed a major motorway.\r\nResidents in some areas around the capital, Canberra, were… [+2371 chars]'}, 
		{'source': 
			{'id': 'bbc-news', 'name': 'BBC News'}, 
			'author': 'https://www.facebook.com/bbcnews', 
			'title': "Australia fires: 113 animal species 'need emergency help'", 
			'description': "Koalas along with birds, fish and frogs need the most help after Australia's fires, says a report.", 
			'url': 'https://www.bbc.co.uk/news/world-australia-51469688', 
			'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/18430/production/_110867399_a9410d19-7a03-4179-95f1-76e2eb5b32cd.jpg', 
			'publishedAt': '2020-02-12T00:06:46Z', 
			'content': 'Image copyrightReutersImage caption\r\n Koalas are one of the 19 mammal species needing urgent help\r\nAustralia has identified 113 animal species which will need "urgent help" after their numbers and habitats were devastated by recent bushfires.\r\nIn a welcome fi… [+2587 chars]'}, 
		{'source': 
			{'id': 'bbc-news', 'name': 'BBC News'}, 
			'author': 'https://www.facebook.com/bbcnews', 
			'title': 'Australia fires: US crew killed in air tanker crash identified', 
			'description': 'The three victims of an air tanker crash had extensive experience fighting fires, their employer says.', 
			'url': 'https://www.bbc.co.uk/news/world-australia-51231983', 
			'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/1207B/production/_110615837_gettyimages-841399516.jpg', 
			'publishedAt': '2020-01-24T04:17:16Z', 
			'content': 'Image copyrightReutersImage caption\r\n The victims (from left) were Ian McBeth, Paul Clyde Hudson and Rick A DeMorgan Jr\r\nThree US firefighters who died when their air tanker crashed while battling blazes in Australia have been identified.\r\nCaptain Ian McBeth,… [+3089 chars]'}, 
		{'source': 
			{'id': 'bbc-news', 'name': 'BBC News'}, 
			'author': 'https://www.facebook.com/bbcnews', 
			'title': 'Australia weather: How much rain did it take to put out NSW fires?', 
			'description': 'A massive dump of water in the past week has turned the fortunes of the fire-hit Australian state.', 
			'url': 'https://www.bbc.co.uk/news/world-australia-51498193', 
			'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/B86A/production/_110901274_82391315_10157619980065552_2908167144040562688_o.jpg', 
			'publishedAt': '2020-02-14T16:11:19Z', 
			'content': "Image copyrightNSWRFS\r\nSince July there have been fires - sometimes hundreds at once - burning across New South Wales, Australia's most populous state.\r\nFirefighters have battled mammoth blazes daily during the state's longest bushfire season. More than five … [+4559 chars]"}, 
		{'source': 
			{'id': 'bbc-news', 'name': 'BBC News'}, 
			'author': 'https://www.facebook.com/bbcnews', 
			'title': "Shane Fitzsimmons: 'Tireless' fire chief steering Australians through disaster", 
			'description': 'Fire chief Shane Fitzsimmons has worked tirelessly and "masterfully" to save lives, close observers say.', 
			'url': 'https://www.bbc.co.uk/news/world-australia-51230844', 
			'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/AD06/production/_110649244_c875e94c-c70e-4392-ba00-f4e2ed1b6b3e.jpg', 
			'publishedAt': '2020-01-30T16:11:18Z', 
			'content': 'Image copyrightEPAImage caption\r\n Rural Fire Service chief Shane Fitzsimmons has drawn wide praise\r\nAustralia\'s bushfires have been described as "apocalyptic" this season. Day after day, images of flames, destruction and smoke have filled television and socia… [+5557 chars]'}, 
		{'source': 
			{'id': 'bbc-news', 'name': 'BBC News'}, 
			'author': 'https://www.facebook.com/bbcnews', 
			'title': 'Australia fires: Thousands in Sydney for Fight Fire Australia concert', 
			'description': 'Australians attend a huge benefit concert in Sydney aiming to raise millions for bushfire relief.', 
			'url': 'https://www.bbc.co.uk/news/world-australia-51520715', 
			'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/14A84/production/_110921648_mediaitem110921647.jpg', 
			'publishedAt': '2020-02-16T08:56:50Z', 
			'content': 'Image copyrightEPA\r\nThousands of Australians are attending a huge benefit concert in Sydney aiming to raise A$10m (£5.15m; $6.71m) to help communities devastated by bushfires.\r\nGlobal acts like Queen and Alice Cooper have joined local stars like 5 Seconds of … [+1970 chars]'}, 
		{'source': 
			{'id': 'bbc-news', 'name': 'BBC News'}, 
			'author': 'BBC News', 
			'title': 'Australia fires: Footage shows speed fires can spread', 
			'description': 'The newly released footage from New South Wales shows how quickly a bushfire can spread.', 
			'url': 'https://www.bbc.co.uk/news/av/world-australia-51304687/australia-fires-footage-shows-speed-fires-can-spread', 
			'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/05D1/production/_110698410_p081rfp2.jpg', 
			'publishedAt': '2020-01-29T23:12:43Z', 
			'content': 'VideoThe footage from 4 January, only released now, shows how quickly a bushfire spreads in New South Wales, Australia.'}
	]
}

# %%
temp['articles']
# Out:
# [{'source': {'id': 'bbc-news', 'name': 'BBC News'},
#   'author': 'https://www.facebook.com/bbcnews',
#   'title': 'Australia firefighters thanked with Times Square billboard',
#   'description': 'The Australian bushfire agency said it wanted to say thanks to helpers in "the biggest way possible".',
#   'url': 'https://www.bbc.co.uk/news/world-australia-51555185',
#   'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/C1E3/production/_110953694_sdfsdfsdfsdfsdfsdf.png',
#   'publishedAt': '2020-02-19T05:32:51Z',
#   'content': 'Image copyrightNSWRFSImage caption\r\n The fire service ran their message in Times Square\r\nAn Australian volunteer firefighting service has used a giant, 21m (70ft) tall billboard in Times Square in New York City to thank crew for their work. \r\nMammoth fires whi… [+2211 chars]'},
#  {'source': {'id': 'bbc-news', 'name': 'BBC News'},
#   'author': 'BBC News',
# ...

# %%
df = pd.DataFrame(temp['articles'])

# %%
df.columns
# Out:
# Index(['source', 'author', 'title', 'description', 'url', 'urlToImage',
#        'publishedAt', 'content', 'sorce'],
#       dtype='object')

# %%
df = df[['title', 'url', 'urlToImage']]

# %%
df
# Out:
#                                                 title  \
# 0   Australia firefighters thanked with Times Squa...
# 1   Australia fires: Blaze 'sparked by helicopter ...
# 2   Australia fires: NSW inquiry to probe climate ...
# 3   Australia fires: State of emergency declared f...
# 4            Fire-hit Australia faces flooding threat
# 5                     Week in Pictures: 18-24 January
# 6   Australia bushfires: Backpackers can stay long...
# 7   Australian bushfire: Didier Drogba to play in ...
# 8   Australia weather: Rain could put out remainin...
# 9   Australia fires: Heavy downbursts extinguish b...
# 10  Australia fires: Residents told to seek shelte...
# 11  Australia fires: 113 animal species 'need emer...
# 12  Australia fires: US crew killed in air tanker ...
# 13  Australia weather: How much rain did it take t...
# 14  Shane Fitzsimmons: 'Tireless' fire chief steer...
# 15  Australia fires: Thousands in Sydney for Fight...
# ...

# %%
df.to_csv('cleanData.csv')
